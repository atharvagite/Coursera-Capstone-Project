# %% [markdown]
# # Segmenting and Clustering Neighbourhoods in Toronto

# %%
import pandas as pd
import numpy as np
import requests

# %%
wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wiki_page = requests.get(wiki)

# %%
wiki_raw = pd.read_html(wiki_page.content, header = 0)[0]
df=wiki_raw[wiki_raw.Neighbourhood !='Not Assigned']
df.reset_index(inplace = True)
df.head()
# Out:
#    index Postal Code           Borough              Neighbourhood
# 0      0         M1A      Not assigned               Not assigned
# 1      1         M2A      Not assigned               Not assigned
# 2      2         M3A        North York                  Parkwoods
# 3      3         M4A        North York           Victoria Village
# 4      4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
df.groupby(['Postal Code']).first()
# Out:
#              index       Borough  \
# Postal Code
# M1A              0  Not assigned
# M1B              9   Scarborough
# M1C             18   Scarborough
# M1E             27   Scarborough
# M1G             36   Scarborough
# M1H             45   Scarborough
# M1J             54   Scarborough
# M1K             63   Scarborough
# M1L             72   Scarborough
# M1M             81   Scarborough
# M1N             90   Scarborough
# M1P             99   Scarborough
# M1R            108   Scarborough
# M1S            117   Scarborough
# M1T            126   Scarborough
# M1V            135   Scarborough
# M1W            144   Scarborough
# M1X            153   Scarborough
# M1Y            162  Not assigned
# M1Z            171  Not assigned
# M2A              1  Not assigned
# M2B             10  Not assigned
# M2C             19  Not assigned
# M2E             28  Not assigned
# M2G             37  Not assigned
# M2H             46    North York
# M2J             55    North York
# M2K             64    North York
# M2L             73    North York
# M2M             82    North York
# ...            ...           ...
# M8N             97  Not assigned
# M8P            106  Not assigned
# M8R            115  Not assigned
# M8S            124  Not assigned
# M8T            133  Not assigned
# M8V            142     Etobicoke
# M8W            151     Etobicoke
# M8X            160     Etobicoke
# M8Y            169     Etobicoke
# M8Z            178     Etobicoke
# M9A              8     Etobicoke
# M9B             17     Etobicoke
# M9C             26     Etobicoke
# M9E             35  Not assigned
# M9G             44  Not assigned
# M9H             53  Not assigned
# M9J             62  Not assigned
# M9K             71  Not assigned
# M9L             80    North York
# M9M             89    North York
# M9N             98          York
# M9P            107     Etobicoke
# M9R            116     Etobicoke
# M9S            125  Not assigned
# M9T            134  Not assigned
# M9V            143     Etobicoke
# M9W            152     Etobicoke
# M9X            161  Not assigned
# M9Y            170  Not assigned
# M9Z            179  Not assigned
#
#                                                  Neighbourhood
# Postal Code
# M1A                                               Not assigned
# M1B                                             Malvern, Rouge
# M1C                     Rouge Hill, Port Union, Highland Creek
# M1E                          Guildwood, Morningside, West Hill
# M1G                                                     Woburn
# M1H                                                  Cedarbrae
# M1J                                        Scarborough Village
# M1K                Kennedy Park, Ionview, East Birchmount Park
# M1L                            Golden Mile, Clairlea, Oakridge
# M1M            Cliffside, Cliffcrest, Scarborough Village West
# M1N                                Birch Cliff, Cliffside West
# M1P          Dorset Park, Wexford Heights, Scarborough Town...
# M1R                                          Wexford, Maryvale
# M1S                                                  Agincourt
# M1T                    Clarks Corners, Tam O'Shanter, Sullivan
# M1V          Milliken, Agincourt North, Steeles East, L'Amo...
# M1W                              Steeles West, L'Amoreaux West
# M1X                                                Upper Rouge
# M1Y                                               Not assigned
# M1Z                                               Not assigned
# M2A                                               Not assigned
# M2B                                               Not assigned
# M2C                                               Not assigned
# M2E                                               Not assigned
# M2G                                               Not assigned
# M2H                                          Hillcrest Village
# M2J                               Fairview, Henry Farm, Oriole
# M2K                                            Bayview Village
# M2L                                   York Mills, Silver Hills
# M2M                                    Willowdale, Newtonbrook
# ...                                                        ...
# M8N                                               Not assigned
# M8P                                               Not assigned
# M8R                                               Not assigned
# M8S                                               Not assigned
# M8T                                               Not assigned
# M8V               New Toronto, Mimico South, Humber Bay Shores
# M8W                                     Alderwood, Long Branch
# M8X              The Kingsway, Montgomery Road, Old Mill North
# M8Y          Old Mill South, King's Mill Park, Sunnylea, Hu...
# M8Z          Mimico NW, The Queensway West, South of Bloor,...
# M9A                    Islington Avenue, Humber Valley Village
# M9B          West Deane Park, Princess Gardens, Martin Grov...
# M9C          Eringate, Bloordale Gardens, Old Burnhamthorpe...
# M9E                                               Not assigned
# M9G                                               Not assigned
# M9H                                               Not assigned
# M9J                                               Not assigned
# M9K                                               Not assigned
# M9L                                              Humber Summit
# M9M                                           Humberlea, Emery
# M9N                                                     Weston
# M9P                                                  Westmount
# M9R          Kingsview Village, St. Phillips, Martin Grove ...
# M9S                                               Not assigned
# M9T                                               Not assigned
# M9V          South Steeles, Silverstone, Humbergate, Jamest...
# M9W                        Northwest, West Humber - Clairville
# M9X                                               Not assigned
# M9Y                                               Not assigned
# M9Z                                               Not assigned
#
# [180 rows x 3 columns]

# %%
len(df['Postal Code'].unique())
# Out:
# 180

# %%
df[df['Borough'] == 'Not assigned']
# Out:
#      index Postal Code       Borough Neighbourhood
# 0        0         M1A  Not assigned  Not assigned
# 1        1         M2A  Not assigned  Not assigned
# 7        7         M8A  Not assigned  Not assigned
# 10      10         M2B  Not assigned  Not assigned
# 15      15         M7B  Not assigned  Not assigned
# 16      16         M8B  Not assigned  Not assigned
# 19      19         M2C  Not assigned  Not assigned
# 24      24         M7C  Not assigned  Not assigned
# 25      25         M8C  Not assigned  Not assigned
# 28      28         M2E  Not assigned  Not assigned
# 29      29         M3E  Not assigned  Not assigned
# 33      33         M7E  Not assigned  Not assigned
# 34      34         M8E  Not assigned  Not assigned
# 35      35         M9E  Not assigned  Not assigned
# 37      37         M2G  Not assigned  Not assigned
# 38      38         M3G  Not assigned  Not assigned
# 42      42         M7G  Not assigned  Not assigned
# 43      43         M8G  Not assigned  Not assigned
# 44      44         M9G  Not assigned  Not assigned
# 51      51         M7H  Not assigned  Not assigned
# 52      52         M8H  Not assigned  Not assigned
# 53      53         M9H  Not assigned  Not assigned
# 60      60         M7J  Not assigned  Not assigned
# 61      61         M8J  Not assigned  Not assigned
# 62      62         M9J  Not assigned  Not assigned
# 69      69         M7K  Not assigned  Not assigned
# 70      70         M8K  Not assigned  Not assigned
# 71      71         M9K  Not assigned  Not assigned
# 78      78         M7L  Not assigned  Not assigned
# 79      79         M8L  Not assigned  Not assigned
# ..     ...         ...           ...           ...
# 132    132         M7T  Not assigned  Not assigned
# 133    133         M8T  Not assigned  Not assigned
# 134    134         M9T  Not assigned  Not assigned
# 136    136         M2V  Not assigned  Not assigned
# 137    137         M3V  Not assigned  Not assigned
# 140    140         M6V  Not assigned  Not assigned
# 141    141         M7V  Not assigned  Not assigned
# 145    145         M2W  Not assigned  Not assigned
# 146    146         M3W  Not assigned  Not assigned
# 149    149         M6W  Not assigned  Not assigned
# 150    150         M7W  Not assigned  Not assigned
# 154    154         M2X  Not assigned  Not assigned
# 155    155         M3X  Not assigned  Not assigned
# 158    158         M6X  Not assigned  Not assigned
# 159    159         M7X  Not assigned  Not assigned
# 161    161         M9X  Not assigned  Not assigned
# 162    162         M1Y  Not assigned  Not assigned
# 163    163         M2Y  Not assigned  Not assigned
# 164    164         M3Y  Not assigned  Not assigned
# 166    166         M5Y  Not assigned  Not assigned
# 167    167         M6Y  Not assigned  Not assigned
# 170    170         M9Y  Not assigned  Not assigned
# 171    171         M1Z  Not assigned  Not assigned
# 172    172         M2Z  Not assigned  Not assigned
# 173    173         M3Z  Not assigned  Not assigned
# 174    174         M4Z  Not assigned  Not assigned
# 175    175         M5Z  Not assigned  Not assigned
# 176    176         M6Z  Not assigned  Not assigned
# 177    177         M7Z  Not assigned  Not assigned
# 179    179         M9Z  Not assigned  Not assigned
#
# [77 rows x 4 columns]

# %%
df.shape
# Out:
# (180, 4)

# %% [markdown]
# # Part 2

# %%
# !pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 8.6MB/s ta 0:00:011
# Requirement already satisfied: future in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: click in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (7.0)
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: decorator in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2020.6.20)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
import geocoder

# %%
url = 'http://cocl.us/Geospatial_data'

# %%
df_geo = pd.read_csv(url)
df_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_geo.dtypes
# Out:
# Postal Code     object
# Latitude       float64
# Longitude      float64
# dtype: object

# %%
df.dtypes
# Out:
# index             int64
# Postal Code      object
# Borough          object
# Neighbourhood    object
# dtype: object

# %%
df.shape
# Out:
# (180, 4)

# %%
df_geo.shape
# Out:
# (103, 3)

# %%
df = df.join(df_geo.set_index('Postal Code'), on='Postal Code')
df
# Out:
#      index Postal Code           Borough  \
# 0        0         M1A      Not assigned
# 1        1         M2A      Not assigned
# 2        2         M3A        North York
# 3        3         M4A        North York
# 4        4         M5A  Downtown Toronto
# 5        5         M6A        North York
# 6        6         M7A  Downtown Toronto
# 7        7         M8A      Not assigned
# 8        8         M9A         Etobicoke
# 9        9         M1B       Scarborough
# 10      10         M2B      Not assigned
# 11      11         M3B        North York
# 12      12         M4B         East York
# 13      13         M5B  Downtown Toronto
# 14      14         M6B        North York
# 15      15         M7B      Not assigned
# 16      16         M8B      Not assigned
# 17      17         M9B         Etobicoke
# 18      18         M1C       Scarborough
# 19      19         M2C      Not assigned
# 20      20         M3C        North York
# 21      21         M4C         East York
# 22      22         M5C  Downtown Toronto
# 23      23         M6C              York
# 24      24         M7C      Not assigned
# 25      25         M8C      Not assigned
# 26      26         M9C         Etobicoke
# 27      27         M1E       Scarborough
# 28      28         M2E      Not assigned
# 29      29         M3E      Not assigned
# ..     ...         ...               ...
# 150    150         M7W      Not assigned
# 151    151         M8W         Etobicoke
# 152    152         M9W         Etobicoke
# 153    153         M1X       Scarborough
# 154    154         M2X      Not assigned
# 155    155         M3X      Not assigned
# 156    156         M4X  Downtown Toronto
# 157    157         M5X  Downtown Toronto
# 158    158         M6X      Not assigned
# 159    159         M7X      Not assigned
# 160    160         M8X         Etobicoke
# 161    161         M9X      Not assigned
# 162    162         M1Y      Not assigned
# 163    163         M2Y      Not assigned
# 164    164         M3Y      Not assigned
# 165    165         M4Y  Downtown Toronto
# 166    166         M5Y      Not assigned
# 167    167         M6Y      Not assigned
# 168    168         M7Y      East Toronto
# 169    169         M8Y         Etobicoke
# 170    170         M9Y      Not assigned
# 171    171         M1Z      Not assigned
# 172    172         M2Z      Not assigned
# 173    173         M3Z      Not assigned
# 174    174         M4Z      Not assigned
# 175    175         M5Z      Not assigned
# 176    176         M6Z      Not assigned
# 177    177         M7Z      Not assigned
# 178    178         M8Z         Etobicoke
# 179    179         M9Z      Not assigned
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                         Not assigned        NaN        NaN
# 1                                         Not assigned        NaN        NaN
# 2                                            Parkwoods  43.753259 -79.329656
# 3                                     Victoria Village  43.725882 -79.315572
# 4                            Regent Park, Harbourfront  43.654260 -79.360636
# 5                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 6          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 7                                         Not assigned        NaN        NaN
# 8              Islington Avenue, Humber Valley Village  43.667856 -79.532242
# 9                                       Malvern, Rouge  43.806686 -79.194353
# 10                                        Not assigned        NaN        NaN
# 11                                           Don Mills  43.745906 -79.352188
# 12                     Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 13                            Garden District, Ryerson  43.657162 -79.378937
# 14                                           Glencairn  43.709577 -79.445073
# 15                                        Not assigned        NaN        NaN
# 16                                        Not assigned        NaN        NaN
# 17   West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 18              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 19                                        Not assigned        NaN        NaN
# 20                                           Don Mills  43.725900 -79.340923
# 21                                    Woodbine Heights  43.695344 -79.318389
# 22                                      St. James Town  43.651494 -79.375418
# 23                                  Humewood-Cedarvale  43.693781 -79.428191
# 24                                        Not assigned        NaN        NaN
# 25                                        Not assigned        NaN        NaN
# 26   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515 -79.577201
# 27                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 28                                        Not assigned        NaN        NaN
# 29                                        Not assigned        NaN        NaN
# ..                                                 ...        ...        ...
# 150                                       Not assigned        NaN        NaN
# 151                             Alderwood, Long Branch  43.602414 -79.543484
# 152                Northwest, West Humber - Clairville  43.706748 -79.594054
# 153                                        Upper Rouge  43.836125 -79.205636
# 154                                       Not assigned        NaN        NaN
# 155                                       Not assigned        NaN        NaN
# 156                        St. James Town, Cabbagetown  43.667967 -79.367675
# 157             First Canadian Place, Underground city  43.648429 -79.382280
# 158                                       Not assigned        NaN        NaN
# 159                                       Not assigned        NaN        NaN
# 160      The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 161                                       Not assigned        NaN        NaN
# 162                                       Not assigned        NaN        NaN
# 163                                       Not assigned        NaN        NaN
# 164                                       Not assigned        NaN        NaN
# 165                               Church and Wellesley  43.665860 -79.383160
# 166                                       Not assigned        NaN        NaN
# 167                                       Not assigned        NaN        NaN
# 168  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 170                                       Not assigned        NaN        NaN
# 171                                       Not assigned        NaN        NaN
# 172                                       Not assigned        NaN        NaN
# 173                                       Not assigned        NaN        NaN
# 174                                       Not assigned        NaN        NaN
# 175                                       Not assigned        NaN        NaN
# 176                                       Not assigned        NaN        NaN
# 177                                       Not assigned        NaN        NaN
# 178  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
# 179                                       Not assigned        NaN        NaN
#
# [180 rows x 6 columns]

# %%
df = df.reset_index()

# %%
df.drop(['index'], axis = 'columns', inplace = True)

# %%
df = df.set_index('level_0')

# %%
df.head()
# Out:
#         Postal Code           Borough              Neighbourhood   Latitude  \
# level_0
# 0               M1A      Not assigned               Not assigned        NaN
# 1               M2A      Not assigned               Not assigned        NaN
# 2               M3A        North York                  Parkwoods  43.753259
# 3               M4A        North York           Victoria Village  43.725882
# 4               M5A  Downtown Toronto  Regent Park, Harbourfront  43.654260
#
#          Longitude
# level_0
# 0              NaN
# 1              NaN
# 2       -79.329656
# 3       -79.315572
# 4       -79.360636

# %%
df = df.rename(index = {'level_0' : 'index'})
df.index.name = 'index'
df.head()
# Out:
#       Postal Code           Borough              Neighbourhood   Latitude  \
# index
# 0             M1A      Not assigned               Not assigned        NaN
# 1             M2A      Not assigned               Not assigned        NaN
# 2             M3A        North York                  Parkwoods  43.753259
# 3             M4A        North York           Victoria Village  43.725882
# 4             M5A  Downtown Toronto  Regent Park, Harbourfront  43.654260
#
#        Longitude
# index
# 0            NaN
# 1            NaN
# 2     -79.329656
# 3     -79.315572
# 4     -79.360636

# %%
df.shape
# Out:
# (180, 5)
